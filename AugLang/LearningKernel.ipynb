# %%
rusText='''
Курс "Общие вопросы патологии и патологической анатомии" предназначен только для студентов, обучающихся на медицинских специальностях и медицинских специалистов. Предупреждение: данный курс содержит материалы, не рекомендованные к просмотру лицам со слабой психикой и беременным женщинам.Курс базируется на многолетнем опыте научной, диагностической и преподавательской работы автора в традициях известной научной школы. Изложение сложного материала проводится на современном уровне, все основные положения иллюстрируются большей частью оригинальными авторскими макро- и микроскопическими изображениями, схемами и рисунками
'''
rusText=rusText.strip()
from googletrans import Translator
from yandex_speech import TTS
translator = Translator(service_urls=[
      'translate.google.cn',
    ])

import IPython
rusText

# good book list
#https://www.fluentu.com/blog/russian/russian-textbooks/
# Out:
# 'Курс "Общие вопросы патологии и патологической анатомии" предназначен только для студентов, обучающихся на медицинских специальностях и медицинских специалистов. Предупреждение: данный курс содержит материалы, не рекомендованные к просмотру лицам со слабой психикой и беременным женщинам.Курс базируется на многолетнем опыте научной, диагностической и преподавательской работы автора в традициях известной научной школы. Изложение сложного материала проводится на современном уровне, все основные положения иллюстрируются большей частью оригинальными авторскими макро- и микроскопическими изображениями, схемами и рисунками'

# %% [markdown]
# ## 翻译

# %%
#translated =translator.translate("предназначен только для студентов", dest='en')
translated =translator.translate("предназначен только для студентов", dest='en')
print(translated.text)
# Out:
# of students

# %% [markdown]
# ## 发音

# %%
#https://pypi.org/project/yandex_speech/
tts = TTS("jane", "mp3", "ae918646-fa47-4e66-96b6-6ce44d6d3146")
#tts.generate("Курс Общие вопросы патологии и патологической анатомии предназначен только для студентов")
tts.generate("Курс Общие вопросы патологии и патологической анатомии предназначен только для студентов")
tts.save("tmp.mp3")
IPython.display.Audio("tmp.mp3")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tts.generate("студентов")
tts.save("tmp.mp3")
IPython.display.Audio("tmp.mp3")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
